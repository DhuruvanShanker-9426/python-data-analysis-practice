# %%
import pandas as pd

# %%
new_dict={
    "anime":["Pokemon","Solo leveling","Dragon Ball"],
    "Days":[1,2,3],
    "sqrt":[1.1,2.2,3.3]
}
new_dict

# %%
pd.DataFrame(new_dict)
# Out:
#            anime  Days  sqrt
# 0        Pokemon     1   1.1
# 1  Solo leveling     2   2.2
# 2    Dragon Ball     3   3.3

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([1,2,3,4,5],
         index=["One","Two","Three","Four","five"],
         name="Numbers")
# Out:
# One      1
# Two      2
# Three    3
# Four     4
# five     5
# Name: Numbers, dtype: int64

# %%
pd.DataFrame(
    [["Pokemon",1,1.2],["Dragon ball",2,1.2]],
    columns=["Anime","Index","Sqrt"]
)
# Out:
#          Anime  Index  Sqrt
# 0      Pokemon      1   1.2
# 1  Dragon ball      2   1.2

# %%
pd.Series(["Pokemon","SAO"],name="Anime")
# Out:
# 0    Pokemon
# 1        SAO
# Name: Anime, dtype: object

# %%
pd.Series(
    [["Pokemon",1,1.2],["Dragon ball",2,1.2]],
    name=["Anime","Index","Sqrt"]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.Series(
#       2     [["Pokemon",1,1.2],["Dragon ball",2,1.2]],
#       3     name=["Anime","Index","Sqrt"]
#       4 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:490, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     481     if not allow_mgr:
#     482         warnings.warn(
#     483             f"Passing a {type(data).__name__} to {type(self).__name__} "
#     484             "is deprecated and will raise in a future version. "
#    (...)    487             stacklevel=2,
#     488         )
# --> 490 name = ibase.maybe_extract_name(name, data, type(self))
#     492 if index is not None:
#     493     index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7765, in maybe_extract_name(name, obj, cls)
# ...

# %%
customers={
    "cust_id":[101,101,101,102,102,102,102,103]
}
cust=pd.DataFrame(customers)
cust
# Out:
#    cust_id
# 0      101
# 1      101
# 2      101
# 3      102
# 4      102
# 5      102
# 6      102
# 7      103

# %%
cust.value_counts()
# Out:
# cust_id
# 102        4
# 101        3
# 103        1
# Name: count, dtype: int64

# %%
print(cust.nunique().sum())
# Out:
# 3
