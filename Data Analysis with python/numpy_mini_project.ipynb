# %%
import numpy as np

# %%
data_file=r"E:\CSV files\makeSenseOfCensus.csv"

# %%
data=np.genfromtxt(data_file,delimiter=",",skip_header=1)
data
# Out:
# array([[39., 13.,  4., ...,  0., 40.,  0.],
#        [50., 13.,  4., ...,  0., 13.,  0.],
#        [38.,  9.,  4., ...,  0., 40.,  0.],
#        ...,
#        [48., 13.,  4., ...,  0., 58.,  1.],
#        [40., 10.,  4., ...,  0., 40.,  0.],
#        [39., 13.,  4., ...,  0., 50.,  1.]], shape=(1000, 8))

# %%
data.shape
# Out:
# (1000, 8)

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.ndim
# Out:
# 2

# %%
#Append The data
d=[[60,15,0,1,0,0,36,1]]
new_data=np.concatenate((data,d),axis=0)
print(new_data)
print(new_data.shape)
# Out:
# [[39. 13.  4. ...  0. 40.  0.]
#  [50. 13.  4. ...  0. 13.  0.]
#  [38.  9.  4. ...  0. 40.  0.]
#  ...
#  [40. 10.  4. ...  0. 40.  0.]
#  [39. 13.  4. ...  0. 50.  1.]
#  [60. 15.  0. ...  0. 36.  1.]]
# (1001, 8)

# %%
data
# Out:
# array([[39., 13.,  4., ...,  0., 40.,  0.],
#        [50., 13.,  4., ...,  0., 13.,  0.],
#        [38.,  9.,  4., ...,  0., 40.,  0.],
#        ...,
#        [48., 13.,  4., ...,  0., 58.,  1.],
#        [40., 10.,  4., ...,  0., 40.,  0.],
#        [39., 13.,  4., ...,  0., 50.,  1.]], shape=(1000, 8))

# %%
print(type(new_data))
new_data
# Out:
# <class 'numpy.ndarray'>
# array([[39., 13.,  4., ...,  0., 40.,  0.],
#        [50., 13.,  4., ...,  0., 13.,  0.],
#        [38.,  9.,  4., ...,  0., 40.,  0.],
#        ...,
#        [40., 10.,  4., ...,  0., 40.,  0.],
#        [39., 13.,  4., ...,  0., 50.,  1.],
#        [60., 15.,  0., ...,  0., 36.,  1.]], shape=(1001, 8))

# %%
#Max age
age=new_data[:,0]
max_age=np.max(age) #age.max()
max_age
# Out:
# np.float64(90.0)

# %%
#Min age
min_age=age.min()
min_age
# Out:
# np.float64(17.0)

# %%
#Mean age
mean_age=np.mean(age)
mean_age
# Out:
# np.float64(38.07292707292707)

# %%
senior_citizen=age[age>60]
senior_citizen
# Out:
# array([79., 67., 76., 61., 70., 64., 71., 68., 66., 64., 90., 66., 75.,
#        65., 64., 61., 65., 77., 62., 76., 63., 66., 67., 65., 62., 63.,
#        80., 67., 63., 72., 62., 74., 67., 72., 69., 65., 65., 71., 70.,
#        66., 65., 61., 61., 68., 64., 64., 62., 73., 72., 63., 62., 61.,
#        71., 63., 63., 67., 81., 64., 67., 78., 63.])

# %%
age>60
# Out:
# array([False, False, False, ..., False, False, False], shape=(1001,))

# %%
working_hrs=new_data[:,6]
avg_hrs=np.mean(working_hrs[age>60])
print(avg_hrs)
# Out:
# 31.42622950819672

# %%
tot_working_hrs=np.sum(working_hrs[age>60])
tot_working_hrs
# Out:
# np.float64(1917.0)

# %%
num_sc=len(senior_citizen)
num_sc
# Out:
# 61

# %%
avg_hrs_using_sum_func=tot_working_hrs/num_sc
avg_hrs_using_sum_func
# Out:
# np.float64(31.42622950819672)

# %%
if avg_hrs>25:
    print("Not follows the govt policy")
else:
    print("Follows the govt policy")
# Out:
# Not follows the govt policy

# %%
edu_num=new_data[:,1]
high=edu_num[edu_num>10]
low=edu_num[edu_num<=10]
print(len(high))
print(len(low))
# Out:
# 328
# 673

# %%
income=new_data[:,7]
avg_high_income=np.mean(income[edu_num>10])
avg_low_income=np.mean(income[edu_num<=10])
print(avg_high_income)
print(avg_low_income)
# Out:
# 0.4298780487804878
# 0.13670133729569092

# %%
if avg_high_income>avg_low_income:
    print("Higher educated people have better general pay")
else:
    print("Higher people doesn't have the better general pay")
# Out:
# Higher educated people have better general pay
